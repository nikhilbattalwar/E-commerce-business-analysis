# %%
import numpy as np
import pandas as pd

# %%
# ls
# Out:
# sample_data/

# %%
# from google.colab import files
# data = files.upload()
# Out:
#      <input type="file" id="files-cc65d76d-f2f3-4531-879a-4d04d2b134d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc65d76d-f2f3-4531-879a-4d04d2b134d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving customers.csv to customers.csv
# Saving products.csv to products.csv
# Saving transactions.csv to transactions.csv

# %%
# ls
# Out:
# customers.csv  products.csv  sample_data/  transactions.csv

# %% [markdown]
# ### **Usecase-1** Load all three csv datasets in Pandas Data frames and display first 5 records

# %%
cust = pd.read_csv('customers.csv',sep=",",index_col=False,names=["custno","firstname","lastname","gender","age","profession","contactNo","emailId","city","state","isActive","createdDate","UpdatedDate"])
cust.sort_values("custno",inplace=True,ignore_index=True)
# print(cust)

prod = pd.read_csv('products.csv',sep=",",index_col=False,names=["productno","productName","Description","isActive","createdDate","UpdatedDate"])
prod.sort_values("productno",inplace=True,ignore_index=True)
# print(prod)

trans = pd.read_csv('transactions.csv',sep=",",index_col=False,names=["txnno","txndate","custno","amount","productno","spendby"])
trans.sort_values("txnno",inplace=True,ignore_index=True)
# print(trans)

cust_trans = pd.merge(left=cust,right=trans,how="inner",on="custno")
# print(cust_trans)

cust_trans_prod = pd.merge(left=cust_trans, right=prod,how="inner",on="productno")
# print(cust_trans_prod)

# %%
pd.merge(left=cust_trans,right=prod,how="inner",on="productno")
# Out:
#      custno firstname   lastname gender  age profession  contactNo  \
# 0         2      Judy      Burks      M   53          S      84759
# 1       682     Janet     Greene      M   52          S      23010
# 2         2      Judy      Burks      M   53          S      84759
# 3       671   Katrina     Horton      F   46          B      46933
# 4       674     Randi       Gray      M   24          S      76442
# ..      ...       ...        ...    ...  ...        ...        ...
# 995     990    Bonnie  Patterson      M   35          S      67095
# 996     992    Tamara       Shaw      M   32          S      78378
# 997     992    Tamara       Shaw      M   32          S      78378
# 998     996   Roxanne  Velazquez      M   37          S      57463
# 999     997   Kristen       Wall      F   20          B      62662
#
#                               emailId           city     state  ... txnno  \
# 0              rfleming@hotma1l.co.uk        Suwanee    Trabue  ...   423
# 1                    adodson@gma1l.us      Lafayette    Auburn  ...   340
# 2              rfleming@hotma1l.co.uk        Suwanee    Trabue  ...   973
# 3    numbersautomatically@hotma1l.biz         Hickox    Leslie  ...   700
# 4                    wefind@yah00.net       Norcross   Airport  ...   950
# ..                                ...            ...       ...  ...   ...
# 995          endprobably@somema1l.net       Montrose   Hickory  ...   460
# 996            soassert83@hotma1l.org        Vidalia  Railroad  ...    73
# 997            soassert83@hotma1l.org        Vidalia  Railroad  ...   377
# 998             warpdays@ma1l2u.co.uk  Crawfordville  Baughman  ...    88
# 999           sreynolds64@ma1lbox.org      Stillwell    Beatty  ...   545
#
#                  txndate amount  productno spendby  productName  Description  \
# 0    2017-10-18 12:31:46   4245        136    Cash   Product136   ecfldqedud
# 1    2017-10-18 12:31:46   3697        136    Card   Product136   ecfldqedud
# 2    2017-10-18 12:31:46   4717        842    Card   Product842   pjcpkksaav
#
# [5 rows x 23 columns]

# %% [markdown]
# ### **Usecase-2** Display only those customers from CSV_s1, who purchased more than 3 products

# %%
cus = cust_trans_prod.groupby(["custno"])["productno"].count()
cus = cus.reset_index()
print(cus[cus["productno"]>3])
# Out:
#      custno  productno
# 2         4          4
# 49       86          4
# 100     167          4
# 111     187          4
# 145     237          4
# 147     241          5
# 193     321          4
# 196     326          4
# 200     331          4
# 219     356          4
# 242     391          5
# 340     537          4
# 355     558          4
# 366     578          4
# 449     709          4
# 463     735          4
# 472     753          4
# 525     828          4
# 641     989          4

# %% [markdown]
# ### **Usecase-3** Display top 5 most demanded products from CSV_s1

# %%
cust_trans_prod["productName"].value_counts().head(5)
# Out:
# Product900    5
# Product768    5
# Product427    5
# Product82     5
# Product637    4
# Name: productName, dtype: int64

# %% [markdown]
# ### **Usecase-4** Display top 5 transactions amount from CSV_s1

# %%
cust_trans_prod["amount"].sort_values(ascending=False).head(5)
# Out:
# 375    4996
# 473    4992
# 25     4981
# 360    4980
# 446    4966
# Name: amount, dtype: int64

# %%
cust_trans_prod.nlargest(5,"amount",keep="all")
# Out:
#      custno firstname   lastname gender  age profession  contactNo  \
# 375     670     Vicki      Frank      M   27          S      84305
# 473     448     Joyce     Slater      M   57          S      47613
# 25      305    Janice  Valentine      F   62          B      23111
# 360     230      Jean  Singleton      M   64          S      30274
# 446     287    Alissa        Roy      F   18          B      85584
#
#                     emailId         city       state  ... txnno  \
# 375  jcolon28@everyma1l.net     Colquitt   Pennisula  ...   557
# 473   spittman@somema1l.biz       Metter   Woodbrook  ...   306
# 25        jglover@gma1l.biz      Tarboro  Thornberry  ...   575
# 360      listwhat@gma1l.com     Rockmart     Warwick  ...   532
# 446    bengland@yah00.co.uk  East Dublin    Hideaway  ...   233
#
#                  txndate amount  productno spendby  productName  Description  \
# 375  2017-10-18 12:31:46   4996        509    Card   Product509   vxzqcrhjxi
# 473  2017-10-18 12:31:46   4992        427    Cash   Product427   rnqzbzweys
# 25   2017-10-18 12:31:46   4981        549    Card   Product549   wzpyhasnxn
# 360  2017-10-18 12:31:46   4980        658    Card   Product658   skwqgxqbbf
# 446  2017-10-18 12:31:45   4966        685    Card   Product685   qoryoiocqa
#
#     isActive_y        createdDate_y        UpdatedDate_y
# 375          Y  2017-08-21 10:11:09  2017-10-18 12:12:39
# 473          Y  2017-09-14 10:44:57  2017-10-18 12:12:38
# 25           Y  2017-09-02 02:06:39  2017-10-18 12:12:39
# 360          Y  2017-06-13 06:50:51  2017-10-18 12:12:39
# 446          Y  2017-07-14 12:23:02  2017-10-18 12:12:39
#
# [5 rows x 23 columns]

# %% [markdown]
# ### **Usecase-5** Display distinct professions from CSV_s1

# %%
cust_trans_prod["profession"].unique()
# Out:
# array(['S', 'B'], dtype=object)

# %% [markdown]
# ### **Usecase-6** Display highest age in CSV_s1 customer’s dataset

# %%
cust.nlargest(1,"age",keep = "all")
# 28 people have age = {nlargest(64)}
# Out:
#      custno  firstname   lastname gender  age profession  contactNo  \
# 58       59    Randall    Lambert      F   64          B      41458
# 142     143     Nathan   Hamilton      F   64          B      81211
# 163     164    Brianna     Vinson      M   64          S      48042
# 169     170      Marie    Hoffman      M   64          S      57181
# 201     202      Lewis       Wynn      M   64          S      64991
# 229     230       Jean  Singleton      M   64          S      30274
# 238     239     Alisha       Luna      F   64          B      28954
# 277     278  Christine     Vinson      M   64          S      89928
# 296     297     Daniel      Weiss      F   64          B      34243
# 297     298       Gary     Norman      M   64          S      89295
# 320     321    Crystal         Le      F   64          B      37857
# 353     354       Dana       Ross      M   64          S      27113
# 393     394       Fred       Rowe      M   64          S      25741
# 465     466     Andrea    Herring      M   64          S      33765
# 500     501     Morgan  Donaldson      F   64          B      52553
# 514     515  Cassandra       Cote      F   64          B      59376
# 520     521     Bonnie     Booker      F   64          B      69371
# 586     587     Dallas   Santiago      F   64          B      52851
# 642     643    Charles      Baker      F   64          B      40232
# 720     721    Charles       Lang      F   64          B      21836
# 754     755      Lewis      Beach      F   64          B      65873
# 763     764     Marvin   Stephens      M   64          S      29257
# 791     792      Erica   Randolph      M   64          S      57376
# 805     806       John       Mays      M   64          S      35395
# 814     815      Roger      Doyle      F   64          B      43933
# 849     850     Kendra       Case      M   64          S      32727
# 943     944      Vicky    Hawkins      M   64          S      51353
# 986     987      Frank  Donaldson      F   64          B      82695
#
#                         emailId              city       state isActive  \
# 58        throwfrom@hotma1l.com           Broxton      Louise        Y
# 142         topull@everyma1l.us        Greenville      Willis        Y
# 163           phahn@b1zmail.net  Avondale Estates  Palmeraway        Y
# 169     islandtrees28@gma1l.org         Clarkston      Euclid        Y
# 201         dpowell@somema1l.us     Dock Junction       Rains        Y
# 229          listwhat@gma1l.com          Rockmart     Warwick        Y
# 238           gweber@ma1l2u.com            Dupont     Skyline        Y
# 277      whilelibrary@gma1l.net          Lithonia      Whaley        Y
# 296     adickerson@somema1l.com            Howell      Barkey        Y
# 297    jwhitfield@everyma1l.biz         Ellabelle     Gilbert        Y
# 320       klawrence@hotma1l.biz       East Dublin       Thorn        Y
# 353      inplane@somema1l.co.uk             Lenox  Greenhouse        Y
# 393     cbattle42@hotma1l.co.uk         Ellaville      Gallia        Y
# 465         bgraham@ma1lbox.org      Cartersville  Montgomery        Y
# 500          ggordon8@yah00.biz          Elberton      Codell        Y
# 514     lockwill0@hotma1l.co.uk         Hardwicke       Stacy        Y
# 520     probablywho@somema1l.us            Morrow      Blaine        Y
# 586          captainto@yah00.us            Potter    Raintree        Y
# 642        computerto@gma1l.biz           Appling    Broadvue        Y
# 720      vpearson@b1zmail.co.uk     New Rock Hill        Best        Y
# 754      rmendoza@hotma1l.co.uk     Holly Springs    Phillips        Y
# 763        awilliams@hotma1l.us            Midway      Orders        Y
# 791          djones@b1zmail.com            Enigma  Springdale        Y
# 805      cavesplane@hotma1l.org           Rebecca    Woodland        Y
# 814            ckey@b1zmail.com            Portal      Lavona        Y
prod_psv.sort_values('productno', inplace=True, ignore_index=True)

trans_psv = pd.read_csv("transactions.txt", sep='|', index_col = False, names = ["txnno","txndate","custno","amount","productno","spendby"])
trans_psv.sort_values('txnno', inplace=True, ignore_index=True)

custtrans_psv = pd.merge(cust_psv, trans_psv, on='custno', how='inner')
custtransprod_psv = pd.merge(custtrans_psv, prod_psv, on='productno', how='inner')

custtransprod_psv.head(5)
# Out:
#    custno firstname lastname gender  age profession  contactNo  \
# 0       2      Judy    Burks      M   53          S      84759
# 1     682     Janet   Greene      M   52          S      23010
# 2       2      Judy    Burks      M   53          S      84759
# 3     671   Katrina   Horton      F   46          B      46933
# 4     674     Randi     Gray      M   24          S      76442
#
#                             emailId       city    state  ... txnno  \
# 0            rfleming@hotma1l.co.uk    Suwanee   Trabue  ...   423
# 1                  adodson@gma1l.us  Lafayette   Auburn  ...   340
# 2            rfleming@hotma1l.co.uk    Suwanee   Trabue  ...   973
# 3  numbersautomatically@hotma1l.biz     Hickox   Leslie  ...   700
# 4                  wefind@yah00.net   Norcross  Airport  ...   950
#
#                txndate amount  productno spendby  productName  Description  \
# 0  2017-10-18 12:31:46   4245        136    Cash   Product136   ecfldqedud
# 1  2017-10-18 12:31:46   3697        136    Card   Product136   ecfldqedud
# 2  2017-10-18 12:31:46   4717        842    Card   Product842   pjcpkksaav
# 3  2017-10-18 12:31:46   2896        842    Card   Product842   pjcpkksaav
# 4  2017-10-18 12:31:46   1918        842    Card   Product842   pjcpkksaav
#
#   isActive_y        createdDate_y        UpdatedDate_y
# 0          Y  2017-01-29 04:02:15  2017-10-18 12:12:38
# 1          Y  2017-01-29 04:02:15  2017-10-18 12:12:38
# 2          Y  2017-08-09 01:24:49  2017-10-18 12:12:39
# 3          Y  2017-08-09 01:24:49  2017-10-18 12:12:39
# 4          Y  2017-08-09 01:24:49  2017-10-18 12:12:39
#
# [5 rows x 23 columns]

# %% [markdown]
# ###  **Usecase-9** Load all three JSON datasets in Pandas Data frames and display first 5 records.

# %%
cust_json = pd.read_json("customers.json", lines=True)
# print(df.head())

prod_json = pd.read_json("products.json", lines=True)
# print(df1.head())

trans_json = pd.read_json("transactions.json", lines=True)
# print(df2.head())

custtrans_json = pd.merge(cust_json, trans_json, on = "custno", how = "inner")
# print(Merge1)

custtransprod_json = pd.merge(custtrans_json, prod_json, on = "productno", how = "outer")
# print(Merge2.head())
custtransprod_json.head()
# Out:
#    custno firstname  lastname  gender   age        profession     contactNo  \
# 0     2.0       Kay      Wise     2.0  26.0  Public Relations  1.674032e+12
# 1    36.0    Xandra      Holt     2.0  41.0          Finances  1.668031e+12
# 2    57.0     Chava  Odonnell     1.0  57.0   Media Relations  1.610121e+12
# 3    85.0    Dalton   Wallace     2.0  27.0  Legal Department  1.655113e+12
# 4     2.0       Kay      Wise     2.0  26.0  Public Relations  1.674032e+12
#
#                                   emailId            city       state  ...  \
# 0                    ridiculus@Sednunc.ca       Oldenzaal  Overijssel  ...
# 1  montes.nascetur@laoreetposuereenim.edu         Rutland     Vermont  ...
# 2               placerat@consectetuer.edu         Reading          PA  ...
# 3                 amet@volutpatnunc.co.uk  Perchtoldsdorf         NÖ.  ...
# 4                    ridiculus@Sednunc.ca       Oldenzaal  Overijssel  ...
#
#    txnno     txndate  amount  productno spendby  productName  Description  \
# 0    8.0  2018-05-22  1124.0         99     1.0          NaN          NaN
# 1   71.0  2018-07-28    15.0         99     2.0          NaN          NaN
# 2   54.0  2018-01-14   106.0         99     1.0          NaN          NaN
# 3  100.0  2017-08-28   273.0         99     2.0          NaN          NaN
# 4   97.0  2017-11-16   672.0         78     1.0          NaN          NaN
#
#    isActive_y createdDate_y UpdatedDate_y
# 0         NaN           NaN           NaN
# 1         NaN           NaN           NaN
# 2         NaN           NaN           NaN
# 3         NaN           NaN           NaN
# 4         NaN           NaN           NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ### **Usecase-10** Load all three XML datasets in Pandas Data frames and display first 5 records.

# %%
cust_xml = pd.read_xml("customers.xml")
cust_xml.sort_values("custno", inplace = True, ignore_index = True)

prod_xml = pd.read_xml("products.xml")
prod_xml.sort_values("productno", inplace = True, ignore_index = True)

trans_xml = pd.read_xml("transactions.xml")
trans_xml.sort_values("txnno", inplace = True, ignore_index = True)

custtrans_xml = pd.merge(cust_xml, trans_xml, on = "custno", how = "inner")
custtransprod_xml = pd.merge(custtrans_xml, prod_xml, on = "productno", how = "outer")

custtransprod_xml.head(5)
# Out:
#    custno firstname lastname  gender   age                profession  \
# 0     1.0    Teegan  Hubbard     2.0  33.0           Human Resources
# 1    21.0      Alan  Camacho     1.0  44.0       Sales and Marketing
# 2    25.0   Barbara  Herrera     1.0  51.0         Quality Assurance
# 3    25.0   Barbara  Herrera     1.0  51.0         Quality Assurance
# 4    92.0    Harper  Padilla     1.0  41.0  Research and Development
#
#       contactNo                          emailId                  city  \
# 0  1.681122e+12        nibh.Quisque@placerat.com            Galashiels
# 1  1.676071e+12  Nunc.mauris@Duiselementumdui.ca  Merrickville-Wolford
# 2  1.653061e+12           purus@eleifendCras.com                Berlin
# 3  1.653061e+12           purus@eleifendCras.com                Berlin
# 4  1.649061e+12      vestibulum.lorem.sit@in.com             St. Asaph
#
#           state  ...  txnno     txndate  amount  productno spendby  \
# 0  Selkirkshire  ...   29.0  2018-09-29  1928.0         80     2.0
# 1            ON  ...   50.0  2017-09-07   569.0         80     1.0
# 2        Berlin  ...   75.0  2018-07-14  1015.0         80     1.0
# 3        Berlin  ...   93.0  2018-11-17   716.0         80     2.0
# 4            FL  ...   40.0  2017-08-04  1584.0         80     2.0
#
#    productName  Description  isActive_y createdDate_y UpdatedDate_y
# 0          NaN          NaN         NaN           NaN           NaN
# 1          NaN          NaN         NaN           NaN           NaN
# 2          NaN          NaN         NaN           NaN           NaN
# 3          NaN          NaN         NaN           NaN           NaN
# 4          NaN          NaN         NaN           NaN           NaN
#
# [5 rows x 23 columns]
